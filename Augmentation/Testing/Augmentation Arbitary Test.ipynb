# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
# Simulating an arbitrary dataset of sensor readings (e.g., flow rate, pressure)
# Each "image" represents a 10x10 grid of sensor data
arbitrary_dataset = np.random.rand(100, 10, 10, 1)  # 100 samples of 10x10 grids

# %%
# Define the ImageDataGenerator for augmentation
datagen = ImageDataGenerator(
    rotation_range=20,        # Random rotations
    width_shift_range=0.2,    # Horizontal shifts
    height_shift_range=0.2,   # Vertical shifts
    zoom_range=0.2,           # Random zooms
    fill_mode='nearest'       # Filling strategy for empty pixels
)

# %%
# Fit the generator on the dataset (optional for non-image data)
datagen.fit(arbitrary_dataset)

# %%
# Generating augmented data
augmented_iterator = datagen.flow(arbitrary_dataset, batch_size=1)

# %%
# Reshape the original sample for visualization
original_sample = arbitrary_dataset[0].reshape(10, 10)

# Use the next() function to get a batch from the iterator
augmented_sample = next(augmented_iterator)[0].reshape(10, 10)

# Plot the original and augmented samples
plt.figure(figsize=(4, 2))

# Original
plt.subplot(1, 2, 1)
plt.title("Original Sample")
plt.imshow(original_sample, cmap="gray")
plt.axis("off")

# Augmented
plt.subplot(1, 2, 2)
plt.title("Augmented Sample")
plt.imshow(augmented_sample, cmap="gray")
plt.axis("off")

plt.tight_layout()
plt.show()

# %%
# Plotting
plt.figure(figsize=(8, 4))

# Original data
plt.subplot(1, 2, 1)
plt.title("Original Data")
plt.imshow(original_sample, cmap='viridis')
plt.colorbar()

# Augmented data
plt.subplot(1, 2, 2)
plt.title("Augmented Data")
plt.imshow(augmented_sample, cmap='viridis')
plt.colorbar()

plt.tight_layout()
plt.show()
